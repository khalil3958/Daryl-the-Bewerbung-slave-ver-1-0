# %%
from lxml import html
import requests
import pandas as pd 
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
from bs4 import BeautifulSoup
import subprocess as sp
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
import os
import argparse
import subprocess
# -*- coding: cp1252 -*-

def fill_and_send (df):
    for index, row in df.iterrows() :
    a=get_the_cover_pdf(row['Institut name'],row['Institute adress'])
    subject=('Bewerbung für die stelle "Studentische hilfskraft" von der '+row['Institut name'])
    body=('sehr geehrte Herr '+row['Name_mod']+'\n\t Im anhang finden Sie meine Bewerbungsunterlagen für die oben genannten Stelle sowie meine Notenspiegel \n\t\t\t\t\t\t\t Ich freue mich von Ihnen zu hören \n\t\t\t\t(Generated by "daryl the bewerung slave Ver0.1")')
    try :
        send_mail(row['Mail'],subject,body,a)
    except : 
        print(index)
        


#####################latex python interaction function and pdf generation##########

def generate_cover_letter():
    os.chdir("C:\\Users\\hp\\Desktop\\ndhif\\test\\data\\")
    os.system("lualatex --interaction=nonstopmode coverletter.tex")


def get_the_cover_pdf(institute,adress):
    
    content = r'''\usepackage[utf8]{inputenc}
    \newcommand{\institute}{%(INSTITUTE)s}
    \newcommand{\adressie}{%(ADRESS)s}'''
    args=dict()
    args['INSTITUTE']=institute
    args['ADRESS']=adress
    with open('var.tex','w',encoding='utf8') as f:
        f.write(content%args)
    cmd = ['lualatex', '-interaction', 'nonstopmode', 'var.tex']
    proc = subprocess.Popen(cmd)
    proc.communicate()
    generate_cover_letter()
    pdf_path=['coverletter.pdf','cv.pdf']
    return pdf_path

############mail sender function##
def send_mail(receiver,subject,body,file_list):

    msg=MIMEMultipart()
    sender = 'khalil.jlif@rwth-aachen.de'
    msg['From']=sender
    msg['To']=receiver
    msg['Subject']=subject

    msg.attach(MIMEText(body,'plain'))

    for filename in file_list:

        attachement=open(filename,'rb')
        part=MIMEBase('application','octet-stream')
        part.set_payload(attachement.read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',"attachement; filename= "+ filename)
        msg.attach(part)

        text=msg.as_string()
    server=smtplib.SMTP('mail.rwth-aachen.de',587 )
    server.starttls()

    server.login('nm741271@rwth-aachen.de','fzaxf9bxf9')
    server.sendmail(sender,receiver,text)
    server.quit()

########data_frame_generator_functions#########
    
def get_rwth_root(number_pages):
    roots=[]
    page=1
    
    while (page<=number_pages):
        print("page",page,"from",number_pages)
        rwth_url=requests.get('https://www.rwth-aachen.de/cms/root/Die-RWTH/Arbeiten-an-der-RWTH/~buym/Jobboerse/?page='+str(page))
        rwth_text=rwth_url.content
        mensa_soup=BeautifulSoup(rwth_text)
        link_in_page = []
        for a in mensa_soup.findAll("a",{'target':'_self'}):
            root =(a.get('href')) 
            if 'Einzelansicht'in root:
                link_in_page.append(root)
                table=(a.string).upper()
                if ("STUDENTISCHE HILFSKRAFT" in table):
                    roots.append(root)
                    
        if len(link_in_page) == 0:
                break
        page=page+1
    return roots


def check_keywords(stringewi , key_words):
        keywords_list=[] 
        big_string=stringewi.upper()
        for i in key_words :
            if i in big_string : 
                keywords_list.append(i)
        return keywords_list

def name_trim (stringie) : 
    aaa=stringie
    to_trim=to_trim=['M. Sc.','Dipl.-Wirt.-Ing.','M.Sc.','Dipl.-Phys. ',' M.Sc',' MSc']
    for i in to_trim:
        if i in stringie :
            aaa=stringie.replace(i,'')
            if 'RWTH' in aaa :
                aaa=aaa.replace('RWTH','')
    return aaa
#key_words=['PYTHON','MATLAB','C++','C#','JAVA','ELEKTROTECH','INFORMATIK','REGELUNG','WEB','MODELLIER','MESSTECH','DATA','DIGITALIS']        

def rwth_bewerbung_data(a,key_words):
    
    my_roots=get_rwth_root(a)
    repertory_list=[]

    for i in range (len(my_roots)):
        
        print("loading",int(i/len(my_roots)*100),"%")
        my_root_string=(my_roots[i])
        rwth_url_jobs=requests.get(my_root_string)
        rwth_url_text=rwth_url_jobs.content
        rwth_url_text_path=html.fromstring(rwth_url_text)
        soup=BeautifulSoup(rwth_url_text)

        for a in soup.findAll("div",{"class":"text"}):
            
            to_search=str(a.findAll('p'))
            found_keywords=check_keywords(to_search,key_words)
            
            if (len(found_keywords)==0):
                break
            #subject_name=a.find('h2').contents[0]
            betreuer_name=a.find('p',{'class':'fn n'}).string
            betreuer_mailie=rwth_url_text_path.xpath('//div[@id="main"]//dd[@class="value"]//a/@href')
            betreuer_mailiee=''.join(betreuer_mailie)
            betreuer_mail=betreuer_mailiee.replace('mailto:','')
            adress_xpath='//div[@id="main"]//table[@style="width: 100%;"]//tbody//tr[3]//td[2]/text()'
            adress=rwth_url_text_path.xpath(adress_xpath)

            if len(adress)==0 or len(adress)==1 : 
                
                adress_xpath='//div[@id="main"]//table[@style="width: 100%;"]//tbody//tr[2]//td[2]/text()'
                adress=rwth_url_text_path.xpath(adress_xpath)

            institut_name=rwth_url_text_path.xpath('//div[@id="main"]//div[@class="text"]//p[1]/text()')[-1]
            initial_repertory={'Found keyword':' '.join(found_keywords),'Name':betreuer_name,'Mail':betreuer_mail,'Institute adress':''.join(adress),'Institute name':institut_name,'Link':my_root_string}
            repertory_list.append(initial_repertory)
    
    bewerbung_infos=pd.DataFrame(repertory_list)
    bewerbung_infos['Name_mod'] = bewerbung_infos.apply(lambda x:name_trim(x['Name']),axis=1)
    return bewerbung_infos
# Out:
#   File "<ipython-input-31-fb9f830c7063>", line 21
#     a=get_the_cover_pdf(row['Institut name'],row['Institute adress'])
#     ^
# IndentationError: expected an indented block

# %%
key_words=['PYTHON','MATLAB','C++','C#','JAVA','ELEKTROTECH','INFORMATIK','REGELUNG','WEB','MODELLIER','MESSTECH','DATA','DIGITALIS']        

rwth_bewerbung_data(10,key_words)
# Out:
# page 1 from 10

# %%
#function that fills everything on latex
dictionnaire={'Name':['khalil boussetta','khalil jlif ','hamdi ghali'] ,'Mail':['khaliltounsi@hotmail.fr','khaliltounsi@hotmail.fr','hamdi.ghali.off@gmail.com'], 'Institute adress':['Lehrstuhl für computergestützte Analyse technischer Systeme Schinkelstraße 2 52062 Aachen','Charukeshi JoglekarInstitute for Automation of...','bachoula fi fourmet mal3ab 52899 aachen'],'Institut name':['Fraunhofer-Institut','Automation of Complex Power Systems','bachoula fi fourmet mal3ab'], 'Link':['http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...','http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...','http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...'],'Name_mod':['khalil bousetta','khalil jlif','hamdi ghali']}
boussetta=pd.DataFrame(dictionnaire)
boussetta
# Out:
#                Name                       Mail  \
# 0  khalil boussetta    khaliltounsi@hotmail.fr
# 1      khalil jlif     khaliltounsi@hotmail.fr
# 2       hamdi ghali  hamdi.ghali.off@gmail.com
#
#                                     Institute adress  \
# 0  Lehrstuhl für computergestützte Analyse techni...
# 1  Charukeshi JoglekarInstitute for Automation of...
# 2            bachoula fi fourmet mal3ab 52899 aachen
#
#                          Institut name  \
# 0                  Fraunhofer-Institut
# 1  Automation of Complex Power Systems
# 2           bachoula fi fourmet mal3ab
#
#                                                 Link         Name_mod
# 0  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...  khalil bousetta
# 1  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...      khalil jlif
# 2  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...      hamdi ghali

# %%
fill_and_send(boussetta)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-29-1a993f17c294> in <module>
# ----> 1 fill_and_send(boussetta)
#
# <ipython-input-24-621490a004f1> in fill_and_send(df)
#      19 def fill_and_send (df):
#      20     for index, row in df.iterrows() :
# ---> 21         a=get_the_cover_pdf(row['Institut name'],row['Institute adress'])
#      22         subject=('Bewerbung für die stelle "Studentische hilfskraft" von der '+row['Institut name'])
#      23         body=('sehr geehrte Herr'+row['Name_mod']+'\n\t Im anhang finden Sie meine bewerbungsunterlagen für die oben genannten stelle sowie meine notenspiegel \n\t\t\t\t\t\t\t Ich freue mich von Ihnen zu hören (this is a generated mail from "daryl the bewerung slave !")')
#
# <ipython-input-24-621490a004f1> in get_the_cover_pdf(institute, adress)
#      49     proc = subprocess.Popen(cmd)
#      50     proc.communicate()
# ---> 51     generate_cover_letter()
#      52     pdf_path=['coverletter.pdf','cv.pdf']
#      53     return pdf_path
#
# <ipython-input-24-621490a004f1> in generate_cover_letter()
#      33 def generate_cover_letter():
#      34     os.chdir("C:\\Users\\hp\\Desktop\\ndhif\\test\\data\\")
# ---> 35     os.system("lualatex --interaction=nonstopmode coverletter.tex")
#      36
#      37
#
# KeyboardInterrupt:

# %%
a
# Out:
#              Found keyword                   Name  \
# 0                   MATLAB   Paul Pramod Muthyala
# 1                   PYTHON          Marvin Berger
# 2     MATLAB C++ MODELLIER    Charukeshi Joglekar
# 3          MATLAB MESSTECH         David Wollborn
# 4        REGELUNG MESSTECH    M. Sc. Jörg Hofmann
# ..                     ...                    ...
# 75        MATLAB MODELLIER                   Deng
# 76     JAVA INFORMATIK WEB   Prof. Dr. Edgar Dahl
# 77  ELEKTROTECH INFORMATIK    Sascha Thamm, M.Sc.
# 78                MESSTECH  Dr.-Ing. Sascha Brose
# 79     MATLAB REGELUNG WEB                 Aubeck
#
#                                          Mail  \
# 0               muthyala_p@vka.rwth-aachen.de
# 1             marvin.berger@ipt.fraunhofer.de
# 2   charukeshi.joglekar@eonerc.rwth-aachen.de
# 3           david.wollborn@avt.rwth-aachen.de
# 4            joerg.hofmann@tos.rwth-aachen.de
# ..                                        ...
# 75                  y.deng@iwm.rwth-aachen.de
# 76                          edahl@ukaachen.de
# 77                 s.thamm@wzl.rwth-aachen.de
# 78            sascha.brose@tos.rwth-aachen.de
# 79                  Aubeck@vka.rwth-aachen.de
#
#                                      Institute adress  \
# 0   Lehrstuhl für Verbrennungskraftmaschinenz. Hd....
# 1   Fraunhofer-Institut für Produktionstechnologie...
# 2   Charukeshi JoglekarInstitute for Automation of...
# 3   David WollbornAVT.BioVTForckenbeckstraße 51520...
# 4   Herr Jörg HofmannLehrstuhl für Technologie Opt...
# ..                                                ...
# 75  Yuanbin DengLehrstuhl und Institut für Werksto...
# 76  RWTH cBMBInstitut für PathologieUniklinik RWTH...
# 77  Werkzeugmaschinenlabor WZL der RWTH AachenCamp...
# 78  Dr.-Ing. Sascha BroseLehrstuhl für Technologie...
# 79  Lehrstuhl für VerbrennungskraftmaschinenM.Sc. ...
#
#                                        Institute name  \
# 0      Lehrstuhl für Verbrennungskraftmaschinen (VKA)
# 1   Fraunhofer-Institut für Produktionstechnologie...
# 2                 Automation of Complex Power Systems
# 3        Lehrstuhl für Bioverfahrenstechnik AVT.BioVT
# 4         Lehrstuhl für Technologie Optischer Systeme
# ..                                                ...
# 75                                                IWM
# 76                                          RWTH cBMB
# 77         Werkzeugmaschinenlabor WZL der RWTH Aachen
# 78        Lehrstuhl für Technologie Optischer Systeme
# 79      Institut für Verbrennungskraftmaschinen (VKA)
#
#                                                  Link               Name_mod
# 0   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...   Paul Pramod Muthyala
# 1   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...          Marvin Berger
# 2   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...    Charukeshi Joglekar
# 3   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...         David Wollborn
# 4   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...           Jörg Hofmann
# ..                                                ...                    ...
# 75  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...                   Deng
# 76  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...   Prof. Dr. Edgar Dahl
# 77  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...         Sascha Thamm,.
# 78  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...  Dr.-Ing. Sascha Brose
# 79  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...                 Aubeck
#
# [80 rows x 7 columns]

# %%
daryl='sehr geehrte Herr name \n\t Im anhang finden Sie meine bewerbungsunterlagen für die oben genannten stelle sowie meine notenspiegel \n\t\t\t\t\t\t\t\t\t\t Ich freue mich von Ihnen zu hören \n\t\t\t\t\t\t\t\t\t(this is a generated mail "daryl bewerung slave")'
print(daryl)
# Out:
# sehr geehrte Herr name
# 	 Im anhang finden Sie meine bewerbungsunterlagen für die oben genannten stelle sowie meine notenspiegel
# 										 Ich freue mich von Ihnen zu hören
# 									(this is a generated mail "daryl bewerung slave")

# %%
get_the_cover_pdf('institüte','ädress')
# Out:
# ['coverletter.pdf', 'cv.pdf']
