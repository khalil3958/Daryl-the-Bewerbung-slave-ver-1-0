# %%
from lxml import html
import requests
import pandas as pd 
from urllib.request import urlopen
from urllib.error import HTTPError
from urllib.error import URLError
from bs4 import BeautifulSoup
import subprocess as sp
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders
            
def send_mail(receiver,subject,body,file_list):

    msg=MIMEMultipart()
    sender = 'khalil.jlif@rwth-aachen.de'
    msg['From']=sender
    msg['To']=receiver
    msg['Subject']=subject

    body='hi this is an email from khalil '
    msg.attach(MIMEText(body,'plain'))

    #file_list=['TD2A_Eco_Web_Scraping_corrige (1).pdf','zzzz.txt']
    for filename in file_list:

        attachement=open(filename,'rb')
        part=MIMEBase('application','octet-stream')
        part.set_payload(attachement.read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',"attachement; filename= "+ filename)
        msg.attach(part)

        text=msg.as_string()
    server=smtplib.SMTP('mail.rwth-aachen.de',587 )
    server.starttls()

    server.login('nm741271@rwth-aachen.de','fzaxf9bxf9')
    server.sendmail(sender,receiver,text)
    server.quit()

def get_rwth_root(number_pages):
    roots=[]
    page=1
    
    while (page<=number_pages):
        print("page",page,"from",number_pages)
        rwth_url=requests.get('https://www.rwth-aachen.de/cms/root/Die-RWTH/Arbeiten-an-der-RWTH/~buym/Jobboerse/?page='+str(page))
        rwth_text=rwth_url.content
        mensa_soup=BeautifulSoup(rwth_text)
        link_in_page = []
        for a in mensa_soup.findAll("a",{'target':'_self'}):
            root =(a.get('href')) 
            if 'Einzelansicht'in root:
                link_in_page.append(root)
                table=(a.string).upper()
                if ("STUDENTISCHE HILFSKRAFT" in table):
                    roots.append(root)
                    
        if len(link_in_page) == 0:
                break
        page=page+1
    return roots

def check_keywords(stringewi , key_words):
        keywords_list=[] 
        big_string=stringewi.upper()
        for i in key_words :
            if i in big_string : 
                keywords_list.append(i)
        return keywords_list

def name_trim (stringie) : 
    to_trim=['M. Sc.','Dipl.-Wirt.-Ing.','M.Sc.',' M.Sc','  RWTH','Dipl.-Phys.']#'Dipl','Wirt','Ing','-','.','M Sc',
    aaa=stringie
    for j in to_trim:
        if j in stringie :
            aaa=stringie.replace(j,'')
    return aaa

#key_words=['PYTHON','MATLAB','C++','C#','JAVA','ELEKTROTECH','INFORMATIK','REGELUNG','WEB','MODELLIER','MESSTECH','DATA','DIGITALIS']        

def rwth_bewerbung_data(a,key_words):
    
    my_roots=get_rwth_root(a)
    repertory_list=[]
    betreuer_names=[]

    for i in range (len(my_roots)):
        
        print("loading",int(i/len(my_roots)*100),"%")
        my_root_string=(my_roots[i])
        rwth_url_jobs=requests.get(my_root_string)
        rwth_url_text=rwth_url_jobs.content
        rwth_url_text_path=html.fromstring(rwth_url_text)
        soup=BeautifulSoup(rwth_url_text)

        for a in soup.findAll("div",{"class":"text"}):
            
            #     p = a.findAll("h3")
         profil_tag = p[10]
     aufgabe_tag = p[11]
            found_keywords=check_keywords(to_search,key_words)
            
            if (len(found_keywords)==0):
                break
            
            betreuer_name=a.find('p',{'class':'fn n'}).contents[0]
            betreuer_names.append(betreuer_name)
            betreuer_mailie=rwth_url_text_path.xpath('//div[@id="main"]//dd[@class="value"]//a/@href')
            betreuer_mailiee=''.join(betreuer_mailie)
            betreuer_mail=betreuer_mailiee.replace('mailto:','')
            adress_xpath='//div[@id="main"]//table[@style="width: 100%;"]//tbody//tr[3]//td[2]/text()'
            adress=rwth_url_text_path.xpath(adress_xpath)

            if len(adress)==0 or len(adress)==1 : 
                
                adress_xpath='//div[@id="main"]//table[@style="width: 100%;"]//tbody//tr[2]//td[2]/text()'
                adress=rwth_url_text_path.xpath(adress_xpath)

            institut_name=rwth_url_text_path.xpath('//div[@id="main"]//div[@class="text"]//p[1]/text()')[-1]
            initial_repertory={'Found keyword':' '.join(found_keywords),'Name':betreuer_name,'Mail':betreuer_mail,'Institute adress':''.join(adress),'Institute name':institut_name ,'Link':my_root_string}
            repertory_list.append(initial_repertory)
    
    bewerbung_infos=pd.DataFrame(repertory_list)
    return bewerbung_infos

bewerbung_infos=rwth_bewerbung_data(10,["DATA"])
bewerbung_infos
# Out:
# page 1 from 10
# page 2 from 10
# page 3 from 10
# page 4 from 10
# page 5 from 10
# page 6 from 10
# page 7 from 10
# page 8 from 10
# loading 0 %
# loading 0 %
# loading 1 %
# loading 2 %
# loading 3 %
# loading 3 %
# loading 4 %
# loading 5 %
# loading 6 %
# loading 6 %
# loading 7 %
# loading 8 %
# loading 9 %
# loading 9 %
# loading 10 %
# loading 11 %
# loading 12 %
# loading 12 %
# loading 13 %
# loading 14 %
# loading 15 %
# loading 16 %
# loading 16 %
# loading 17 %
# loading 18 %
# loading 19 %
# loading 19 %
# loading 20 %
# loading 21 %
# loading 22 %
# loading 22 %
# loading 23 %
# loading 24 %
# loading 25 %
# loading 25 %
# loading 26 %
# loading 27 %
# loading 28 %
# loading 29 %
# loading 29 %
# loading 30 %
# loading 31 %
# loading 32 %
# loading 32 %
# loading 33 %
# loading 34 %
# loading 35 %
# loading 35 %
# loading 36 %
# loading 37 %
# loading 38 %
# loading 38 %
# loading 39 %
# loading 40 %
# loading 41 %
# loading 41 %
# loading 42 %
# loading 43 %
# loading 44 %
# loading 45 %
# loading 45 %
# loading 46 %
# loading 47 %
# loading 48 %
# loading 48 %
# loading 49 %
# loading 50 %
# loading 51 %
# loading 51 %
# loading 52 %
# loading 53 %
# loading 54 %
# loading 54 %
# loading 55 %
# loading 56 %
# loading 57 %
# loading 58 %
# loading 58 %
# loading 59 %
# loading 60 %
# loading 61 %
# loading 61 %
# loading 62 %
# loading 63 %
# loading 64 %
# loading 64 %
# loading 65 %
# loading 66 %
# loading 67 %
# loading 67 %
# loading 68 %
# loading 69 %
# loading 70 %
# loading 70 %
# loading 71 %
# loading 72 %
# loading 73 %
# loading 74 %
# loading 74 %
# loading 75 %
# loading 76 %
# loading 77 %
# loading 77 %
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     376             try:  # Python 2.7, use buffering of HTTP responses
# --> 377                 httplib_response = conn.getresponse(buffering=True)
#     378             except TypeError:  # Python 3
#
# TypeError: getresponse() got an unexpected keyword argument 'buffering'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-500c0354fbc0> in <module>
#     126     return bewerbung_infos
#     127
# --> 128 bewerbung_infos=rwth_bewerbung_data(10,["DATA"])
#     129 bewerbung_infos
#
# <ipython-input-1-500c0354fbc0> in rwth_bewerbung_data(a, key_words)
#      93         print("loading",int(i/len(my_roots)*100),"%")
#      94         my_root_string=(my_roots[i])
# ---> 95         rwth_url_jobs=requests.get(my_root_string)
#      96         rwth_url_text=rwth_url_jobs.content
#      97         rwth_url_text_path=html.fromstring(rwth_url_text)
#
# C:\Anaconda3\lib\site-packages\requests\api.py in get(url, params, **kwargs)
#      73
#      74     kwargs.setdefault('allow_redirects', True)
# ---> 75     return request('get', url, params=params, **kwargs)
#      76
#      77
#
# C:\Anaconda3\lib\site-packages\requests\api.py in request(method, url, **kwargs)
#      58     # cases, and look like a memory leak in others.
#      59     with sessions.Session() as session:
# ---> 60         return session.request(method=method, url=url, **kwargs)
#      61
#      62
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in <listcomp>(.0)
#     666
#     667         # Resolve redirects if allowed.
# --> 668         history = [resp for resp in gen] if allow_redirects else []
#     669
#     670         # Shuffle things around if there's history.
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in resolve_redirects(self, resp, req, stream, timeout, verify, cert, proxies, yield_requests, **adapter_kwargs)
#     245                     proxies=proxies,
#     246                     allow_redirects=False,
# --> 247                     **adapter_kwargs
#     248                 )
#     249
#
# C:\Anaconda3\lib\site-packages\requests\sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# C:\Anaconda3\lib\site-packages\requests\adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     447                     decode_content=False,
#     448                     retries=self.max_retries,
# --> 449                     timeout=timeout
#     450                 )
#     451
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     598                                                   timeout=timeout_obj,
#     599                                                   body=body, headers=headers,
# --> 600                                                   chunked=chunked)
#     601
#     602             # If we're going to release the connection in ``finally:``, then
#
# C:\Anaconda3\lib\site-packages\urllib3\connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     378             except TypeError:  # Python 3
#     379                 try:
# --> 380                     httplib_response = conn.getresponse()
#     381                 except Exception as e:
#     382                     # Remove the TypeError from the exception chain in Python 3;
#
# C:\Anaconda3\lib\http\client.py in getresponse(self)
#    1319         try:
#    1320             try:
# -> 1321                 response.begin()
#    1322             except ConnectionError:
#    1323                 self.close()
#
# C:\Anaconda3\lib\http\client.py in begin(self)
#     294         # read until we get a non-100 response
#     295         while True:
# --> 296             version, status, reason = self._read_status()
#     297             if status != CONTINUE:
#     298                 break
#
# C:\Anaconda3\lib\http\client.py in _read_status(self)
#     255
#     256     def _read_status(self):
# --> 257         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     258         if len(line) > _MAXLINE:
#     259             raise LineTooLong("status line")
#
# C:\Anaconda3\lib\socket.py in readinto(self, b)
#     587         while True:
#     588             try:
# --> 589                 return self._sock.recv_into(b)
#     590             except timeout:
#     591                 self._timeout_occurred = True
#
# C:\Anaconda3\lib\site-packages\urllib3\contrib\pyopenssl.py in recv_into(self, *args, **kwargs)
#     292     def recv_into(self, *args, **kwargs):
#     293         try:
# --> 294             return self.connection.recv_into(*args, **kwargs)
#     295         except OpenSSL.SSL.SysCallError as e:
#     296             if self.suppress_ragged_eofs and e.args == (-1, 'Unexpected EOF'):
#
# C:\Anaconda3\lib\site-packages\OpenSSL\SSL.py in recv_into(self, buffer, nbytes, flags)
#    1811             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1812         else:
# -> 1813             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1814         self._raise_ssl_error(self._ssl, result)
#    1815
#
# KeyboardInterrupt:

# %%
bewerbung_infos
# Out:
#    Found keyword                          Name  \
# 0         PYTHON                    Felix Pütz
# 1         PYTHON                   Tommy Venek
# 2         PYTHON        M. Sc. Niklas Prätzsch
# 3         PYTHON          M.Sc. Johannes Mayer
# 4         PYTHON          M.Sc. Johannes Mayer
# 5         PYTHON              Christian Möbitz
# 6         PYTHON                  Sören Münker
# 7         PYTHON            Pit Heimes, M. Sc.
# 8         PYTHON            Pit Heimes, M. Sc.
# 9         PYTHON                       Ruppert
# 10        PYTHON                       Ruppert
# 11        PYTHON     Dipl.-Phys. Jochen Vieker
# 12        PYTHON     Dipl.-Phys. Jochen Vieker
# 13        PYTHON  M.Sc. Alexander Albert Meyer
# 14        PYTHON      Dipl.-Phys. Marco Hoefer
#
#                                     Mail  \
# 0        felix.puetz@iehk.rwth-aachen.de
# 1          tommy.venek@ipt.fraunhofer.de
# 2     niklas.praetzsch@ilt.fraunhofer.de
# 3             J.Mayer@wzl.rwth-aachen.de
# 4             J.Mayer@wzl.rwth-aachen.de
# 5   christian.moebitz@ita.rwth-aachen.de
# 6           s.muenker@wzl.rwth-aachen.de
# 7          Pit.Heimes@fir.rwth-aachen.de
# 8          Pit.Heimes@fir.rwth-aachen.de
# 9             ruppert@vka.rwth-aachen.de
# 10            ruppert@vka.rwth-aachen.de
# 11       jochen.vieker@ilt.fraunhofer.de
# 12       jochen.vieker@ilt.fraunhofer.de
# 13     alexander.meyer@ilt.fraunhofer.de
# 14        marco.hoefer@ilt.fraunhofer.de
#
#                                      Institute adress  \
# 0                 Felix PützIntzestraße 152072 Aachen
# 1   Fraunhofer-Institut für Produktionstechnologie...
# 2   Herrn Niklas PrätzschFraunhofer-Institut für L...
# 3   M.Sc. Johannes Mayer    WZL der RWTH AachenDat...
# 4   M.Sc. Johannes Mayer    WZL der RWTH AachenDat...
# 5   Institut für TextiltechnikChristian MöbitzOtto...
# 6                  WZLCampus-Boulevard 3052074 Aachen
# 7   FIR an der RWTH Aachen  Pit Heimes, M.Sc. Camp...
# 8   FIR an der RWTH Aachen  Pit Heimes, M.Sc. Camp...
# 9   Lehrstuhl für Verbrennungskraftmaschinenz. Hd....
# 10  Lehrstuhl für Verbrennungskraftmaschinenz. Hd....
# 11  Dipl.-Phys. Jochen ViekerFraunhofer-Institut f...
# 12  Dipl.-Phys. Jochen ViekerFraunhofer-Institut f...
# 13  Fraunhofer-Institut für Lasertechnik ILTSteinb...
# 14  Dipl.-Phys. Marco HoeferFraunhofer-Institut fü...
#
#                                        Institute name  \
# 0   Lehr- und Forschungsgebiet für Werkstoff- und ...
# 1   Fraunhofer-Institut für Produktionstechnologie...
# 2                Fraunhofer-Institut für Lasertechnik
# 3              Werkzeugmaschinenlabor der RWTH Aachen
# 4                     Werkzeugmaschinenlabor der RWTH
# 5                    Institut für Textiltechnik (ITA)
# 6                          Werkzeugmaschinenlabor WZL
# 7                              FIR an der RWTH Aachen
# 8                              FIR an der RWTH Aachen
# 9       Institut für Verbrennungskraftmaschinen (VKA)
# 10      Institut für Verbrennungskraftmaschinen (VKA)
# 11                         Lehrstuhl für Lasertechnik
# 12               Fraunhofer-Institut für Lasertechnik
# 13           Fraunhofer-Institut für Lasertechnik ILT
# 14               Fraunhofer-Institut für Lasertechnik
#
#                                                  Link
# 0   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 1   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 2   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 3   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 4   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 5   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 6   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 7   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 8   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 9   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 10  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 11  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 12  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 13  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 14  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...

# %%
#function to trim the name

# %%
bewerb_df = bewerbung_infos.copy()

# %%
type(betreuer_names[1])
# Out:
# bs4.element.NavigableString

# %%
bewerb_df.columns
# Out:
# Index(['Found keyword', 'Name', 'Mail', 'Institute adress', 'Institute name',
#        'Link'],
#       dtype='object')

# %%
bewerb_df['Name_mod'] = bewerb_df.apply(lambda x:name_trim(x['Name']),axis=1)

# %%
bewerb_df
# Out:
#                       Found keyword                             Name  \
# 0                   MATLAB MESSTECH                   David Wollborn
# 1                 REGELUNG MESSTECH              M. Sc. Jörg Hofmann
# 2   ELEKTROTECH INFORMATIK MESSTECH      Dr.-Ing. Christopher Brandl
# 3         INFORMATIK DATA DIGITALIS  Dipl.-Wirt.-Ing. Thomas Vollmer
# 4                               WEB            Sebastian Weber M.Sc.
# ..                              ...                              ...
# 82                 MATLAB MODELLIER                             Deng
# 83              JAVA INFORMATIK WEB             Prof. Dr. Edgar Dahl
# 84           ELEKTROTECH INFORMATIK              Sascha Thamm, M.Sc.
# 85                         MESSTECH            Dr.-Ing. Sascha Brose
# 86              MATLAB REGELUNG WEB                           Aubeck
#
#                                                  Mail  \
# 0                   david.wollborn@avt.rwth-aachen.de
# 1                    joerg.hofmann@tos.rwth-aachen.de
# 2                         c.brandl@iaw.rwth-aachen.de
# 3   studierende.produktionsqualitaet@ipt.fraunhofe...
# 4   bewerbung.technologieorganisation@ipt.fraunhof...
# ..                                                ...
# 82                          y.deng@iwm.rwth-aachen.de
# 83                                  edahl@ukaachen.de
# 84                         s.thamm@wzl.rwth-aachen.de
# 85                    sascha.brose@tos.rwth-aachen.de
# 86                          Aubeck@vka.rwth-aachen.de
#
#                                      Institute adress  \
# 0   David WollbornAVT.BioVTForckenbeckstraße 51520...
# 1   Herr Jörg HofmannLehrstuhl für Technologie Opt...
# 2   Institut für ArbeitswissenschaftDr.-Ing. Chris...
# 3   Fraunhofer-Institut für Produktionstechnologie...
# 4   Fraunhofer-Institut für Produktionstechnologie...
# ..                                                ...
# 82  Yuanbin DengLehrstuhl und Institut für Werksto...
# 83  RWTH cBMBInstitut für PathologieUniklinik RWTH...
# 84  Werkzeugmaschinenlabor WZL der RWTH AachenCamp...
# 85  Dr.-Ing. Sascha BroseLehrstuhl für Technologie...
# 86  Lehrstuhl für VerbrennungskraftmaschinenM.Sc. ...
#
#                                        Institute name  \
# 0        Lehrstuhl für Bioverfahrenstechnik AVT.BioVT
# 1         Lehrstuhl für Technologie Optischer Systeme
# 2                    Institut für Arbeitswissenschaft
# 3   Fraunhofer-Institut für Produktionstechnologie...
# 4   Fraunhofer-Institut für Produktionstechnologie...
# ..                                                ...
# 82                                                IWM
# 83                                          RWTH cBMB
# 84         Werkzeugmaschinenlabor WZL der RWTH Aachen
# 85        Lehrstuhl für Technologie Optischer Systeme
# 86      Institut für Verbrennungskraftmaschinen (VKA)
#
#                                                  Link  \
# 0   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 1   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 2   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 3   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 4   http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# ..                                                ...
# 82  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 83  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 84  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 85  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
# 86  http://www.rwth-aachen.de/cms/root/Die-RWTH/Ar...
#
#                        Name_mod
# 0                David Wollborn
# 1                  Jörg Hofmann
# 2   Dr.-Ing. Christopher Brandl
# 3                Thomas Vollmer
# 4              Sebastian Weber.
# ..                          ...
# 82                         Deng
# 83         Prof. Dr. Edgar Dahl
# 84               Sascha Thamm,.
# 85        Dr.-Ing. Sascha Brose
# 86                       Aubeck
#
# [87 rows x 7 columns]

# %%
import smtplib
from email.mime.text import MIMEText
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email import encoders


def send_mail(receiver,subject,body,file_list):

    msg=MIMEMultipart()
    sender = 'khalil.jlif@rwth-aachen.de'
    msg['From']=sender
    msg['To']=receiver
    msg['Subject']=subject

    body='hi this is an email from khalil '
    msg.attach(MIMEText(body,'plain'))

    #file_list=['TD2A_Eco_Web_Scraping_corrige (1).pdf','zzzz.txt']
    for filename in file_list:

        attachement=open(filename,'rb')
        part=MIMEBase('application','octet-stream')
        part.set_payload(attachement.read())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition',"attachement; filename= "+ filename)
        msg.attach(part)

        text=msg.as_string()
    server=smtplib.SMTP('mail.rwth-aachen.de',587 )
    server.starttls()

    server.login('nm741271@rwth-aachen.de','fzaxf9bxf9')
    server.sendmail(sender,receiver,text)
    server.quit()

# %%
send_mail('khaliltounsi@hotmail.fr','you are trash','hi sir you are trash', ['zzzz.txt','TD2A_Eco_Web_Scraping_corrige (1).pdf'])

# %% [markdown]
# ### Extract Ihre Profil / Aufgaben

# %%
template_string = 'http://www.rwth-aachen.de/cms/root/Die-RWTH/Arbeiten-an-der-RWTH/Jobboerse/~kbag/JOB-Einzelansicht/file/29889/'
rwth_url_jobs=requests.get(template_string)
rwth_url_text=rwth_url_jobs.content
rwth_url_text_path=html.fromstring(rwth_url_text)
soup=BeautifulSoup(rwth_url_text)

for a in soup.findAll("div",{"class":"text"}):
#     p = a.findAll("h3")
#     profil_tag = p[10]
#     aufgabe_tag = p[11]

# %%
#print("loading",int(i/len(my_roots)*100),"%")
my_roots=get_rwth_root(2)
for my_root_string in my_roots[:5]:
    #my_root_string=(my_roots[0])
    rwth_url_jobs=requests.get(my_root_string)
    rwth_url_text=rwth_url_jobs.content
    rwth_url_text_path=html.fromstring(rwth_url_text)
    soup=BeautifulSoup(rwth_url_text)

    for a in soup.findAll("div",{"class":"text"}):
        p = a.findAll("h3")
        #print(p)
        print('Profil: \n')
        print(p[p.index(profil_tag)].next_sibling)
        print('Aufgaben: \n')
        print(p[p.index(aufgabe_tag)].next_sibling)
# Out:
# page 1 from 2
# page 2 from 2
# Profil:
#
# <p>- Sie haben Spaß an Programmierung und Simulation <br/>
# - Sie streben eine Beschäftigungsdauer von mindestens einem halben Jahr an<br/>
# - Sie sind Studierender der Fachrichtungen Maschinenbau, CES oder vergleichbarer Studiengänge<br/>
# - Sie verfügen über Grundkenntnisse im Umgang mit Unix-basierten Betriebssystemen</p>
# Aufgaben:
#
# <p>- Verwendung verschiedener leistungsfähiger Bibliotheken zur Netzgenerierung von komplexen Domänen in 4D<br/><br/>
# Bitte beachten Sie auch die Ausschreibung auf der Institushomepage: http://www.cats.rwth-aachen.de/</p>
# Profil:
#
# <p>- eingeschriebener Student (w/m/d) an einer Hoch- oder Fachhochschule<br/>
# - sehr gute Deutsch- und gute Englischkenntnisse in Wort und Schrift <br/>
# - gute Kenntnisse in MS-Office <br/>
# - hohes Engagement und eine strukturierte, selbstständige Denk- und Arbeitsweise</p>
# Aufgaben:
#
# <p>- administrative Tätigkeiten in der Verwaltung<br/>
# - Unterstützung des Personalwesens</p>
# Profil:
#
# <p>- eingeschriebener Studierender (w/m/d) an einer Hoch- oder Fachhochschule<br/>
# - sehr gute Deutsch- und gute Englischkenntnisse in Wort und Schrift<br/>
# - Grundkenntnisse in MS Office (Word, Excel, PowerPoint)<br/>
# - Hohes Engagement und strukturierte, selbstständige Denk- und Arbeitsweise</p>
# Aufgaben:
#
# <p>- Besucherempfang-/ organisation  <br/>
# - Allgemeine Verwaltungskorrespondenz<br/>
# - Verkauf studentischer Lehrmittel <br/>
# - Unterstützung des PR/Medien-Teams</p>
# Profil:
#
# <p>- Du studierst Maschinenbau, Wirtschaftsingenieurwesen oder ein vergleichbares Fach<br/>
# - Du besitzt ein hohes Maß an Eigeninitiative und Teamgeist<br/>
# - Du hast gute Sprachkenntnisse in Deutsch und Englisch<br/>
# - Interesse an einer längerfristigen Beschäftigung<br/>
# - Idealerweise verfügst du bereits über Kenntnisse im Bereich Faserverbundwerkstoffe und/oder der Produktionstechnik </p>
# Aufgaben:
#
# <p>Die Abteilung »Hochleistungszerspanung« entwickelt Technologien und anwendungsnahe Lösungen für unterschiedlichste Zerspanungsaufgaben - vor allem für das simultane Mehrachsfräsen und das Drehen geometrisch anspruchsvoller Bauteile aus Superlegierungen, hochharten Stählen, Leichtbau- und Verbundmaterialien oder Sonderwerkstoffen. Zur Unterstützung unserer Aktivitäten in dem Bereich Zerspanung von Verbundwerkstoffen suchen wir ab sofort eine motivierte studentische Hilfskraft (m/w/d) auf Basis von 12 Wochenstunden.<br/><br/>
# - Unterstützung bei der Planung von Versuchsreihen<br/>
# - Durchführung von Zerspanversuchen an der Maschine<br/>
# - Auswertung, Dokumentation und Interpretation von Versuchsergebnissen<br/>
# - Literaturrecherchen zu ausgewählten technologischen Themen<br/>
# - Selbstständige Planung von Teilprojekten für Forschung und Industrie<br/><br/>
# Was wir bieten:<br/>
# - Ideale Rahmenbedingungen für Praxiserfahrungen neben dem Studium<br/>
# - Spannende Einblicke in aktuelle Forschungsthemen<br/>
# - Flexible Arbeitszeiten und Berücksichtigung von Prüfungsphasen<br/>
# - Mitarbeit in einem engagierten Team</p>
# Profil:
#
# <p>Gute Kenntnisse im EDV-Bereich, vor allem Microsoft Windows.<br/><br/>
# Guter Umgang mit den gänigen Officeprogrammen, vorteilhaft sind Kenntnisse in Vectorworks und ArcGis.<br/><br/>
# Motivation, sich in neue Themenfelder einzuarbeiten<br/>
# Zuverlässigkeit und Gewissenhaftigkeit</p>
# Aufgaben:
#
# <p>allgemeine Administrative Tätigkeiten,<br/>
# Beschaffung von EDV-Geräten und deren Verwaltung mit der gängigen Microsoft Windows Software.</p>
